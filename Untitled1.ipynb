# %%
from scipy.io.wavfile import read
from IPython.display import Audio, display

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier

import matplotlib.pyplot as plt
import numpy as np
import librosa
import os

# %%
dataset = "dataset/splitted"
num_labels = 10

# %%
labels = []
audios = []
for label in range(num_labels):
    label_path = f"{dataset}/{label}"
    for file in sorted(os.listdir(label_path)):
        file_path = label_path + "/" + file
        sample_rate, audio = read(file_path)
        labels.append(label)
        audios.append(audio)

# %%
np.array([0, 5, 2, 3]) * 2
# Out:
# array([ 0, 10,  4,  6])

# %%
audios[0].shape[0]
# Out:
# 24000

# %%
plt.plot(audios[0])

# %%
audios[0].shape[0] / sample_rate
# Out:
# 0.5

# %%
max_duration_sec = 0.6
max_duration = round(max_duration_sec * sample_rate)
audio = audios[0]
audio = np.pad(audio, (0, max_duration - len(audio)), constant_values=0)
audio
# Out:
# array([272, 235, 246, ...,   0,   0,   0], dtype=int16)

# %%
plt.plot(audio)

# %%
feature = librosa.feature.melspectrogram(audio.astype(float), sample_rate, n_mels=32, fmax=1000)
feature.min(), feature.max()
# Out:
# (0.0, 672832481160.5399)

# %%
plt.figure(figsize=(5, 15))
plt.imshow(feature)

# %%
feature = librosa.amplitude_to_db(feature)
feature.min(), feature.max()
# Out:
# (156.558138979468, 236.558138979468)

# %%
plt.figure(figsize=(5, 15))
plt.imshow(feature)

# %%
max_duration_sec = 0.6
max_duration = round(max_duration_sec * sample_rate)

# %%
features = []
features_flatten = []
labels_flatten = []
for audio, label in zip(audios, labels):
    if len(audio) < max_duration:
        audio = np.pad(audio, (0, max_duration - len(audio)), constant_values=0)
    if len(audio) > max_duration:
        continue
    # audio := (audio - mean) / std
    feature = librosa.feature.melspectrogram(audio.astype(float), sample_rate, n_mels=16, fmax=1000)
    # feature := amplitude_to_db(feature)
    features.append(feature)
    features_flatten.append(feature.reshape(-1))
    labels_flatten.append(label)

# %%
def plot(idx):
    plt.figure(figsize=(20, 5))

    plt.subplot(1, 2, 1)
    plt.title(f"{labels[idx]}")
    plt.plot(audios[idx])

    plt.subplot(1, 2, 2)
    plt.title(f"{labels[idx]}")
    plt.imshow(features[idx])

    display(Audio(audios[idx], rate=sample_rate))
plot(4)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
features_train, features_test, labels_train, labels_test = train_test_split(features_flatten, labels_flatten, random_state=1755)

# %%
len(features_train), features_train[1].shape
# Out:
# (2278, (912,))

# %%
len(labels_train), labels_train[1]
# Out:
# (2278, 2)

# %%
len(features_test), features_test[1].shape
# Out:
# (760, (912,))

# %%
len(labels_test), labels_test[1]
# Out:
# (760, 2)

# %%
model = RandomForestClassifier(max_depth=25, n_estimators=30, max_features=1)

# %%
model.fit(X=features_train, y=labels_train)
# Out:
# RandomForestClassifier(max_depth=25, max_features=1, n_estimators=30)

# %%
# !mkdir models
# Out:
# Подпапка или файл models уже существует.

# %%
import pickle

with open("models/model.pkl", "wb") as f:
    pickle.dump(model, f)

# %%
labels_test_predicted = model.predict(X=features_test)

# %%
(labels_test_predicted == labels_test).mean()
# Out:
# 0.7776315789473685

# %%
print(labels_test)
print(labels_test_predicted.tolist())
# Out:
# [4, 2, 4, 7, 7, 1, 6, 8, 5, 5, 6, 4, 7, 6, 1, 6, 0, 0, 0, 2, 0, 5, 9, 8, 8, 9, 6, 0, 9, 5, 4, 2, 7, 8, 8, 7, 5, 3, 2, 3, 5, 7, 5, 2, 9, 1, 5, 7, 0, 1, 1, 7, 4, 6, 7, 9, 1, 3, 4, 1, 9, 3, 1, 9, 9, 8, 8, 9, 4, 7, 1, 9, 1, 6, 2, 6, 3, 9, 1, 3, 0, 5, 6, 0, 2, 0, 7, 2, 5, 7, 9, 2, 1, 5, 6, 4, 7, 7, 9, 7, 2, 0, 7, 9, 2, 0, 2, 1, 7, 4, 6, 4, 2, 6, 1, 7, 9, 5, 7, 4, 8, 6, 4, 6, 8, 6, 3, 9, 0, 9, 6, 7, 5, 1, 7, 2, 2, 7, 5, 0, 3, 2, 8, 9, 2, 0, 8, 9, 1, 3, 9, 1, 0, 6, 8, 6, 5, 4, 6, 1, 6, 4, 6, 3, 9, 6, 9, 7, 8, 5, 5, 6, 9, 6, 7, 0, 0, 6, 8, 5, 9, 1, 6, 9, 1, 7, 2, 3, 2, 8, 9, 5, 8, 3, 6, 4, 3, 1, 4, 5, 2, 4, 3, 2, 2, 2, 4, 1, 2, 8, 0, 3, 1, 7, 9, 6, 9, 2, 8, 2, 6, 0, 0, 3, 9, 5, 1, 7, 2, 7, 2, 2, 1, 9, 6, 6, 8, 9, 3, 0, 5, 0, 1, 6, 7, 7, 8, 4, 2, 9, 6, 7, 2, 9, 7, 1, 2, 6, 3, 2, 1, 1, 9, 3, 7, 3, 9, 3, 3, 9, 2, 6, 8, 7, 4, 0, 4, 4, 8, 6, 0, 3, 3, 5, 7, 4, 1, 7, 6, 2, 6, 2, 8, 1, 2, 3, 8, 5, 1, 1, 1, 3, 6, 1, 6, 9, 0, 3, 0, 7, 8, 1, 5, 1, 7, 1, 1, 5, 5, 8, 4, 9, 8, 9, 4, 1, 5, 9, 3, 1, 0, 7, 1, 1, 7, 2, 5, 1, 7, 5, 7, 6, 9, 8, 0, 7, 2, 1, 0, 6, 9, 5, 3, 5, 1, 3, 0, 7, 1, 7, 5, 9, 8, 3, 8, 8, 6, 7, 6, 4, 5, 3, 9, 5, 7, 3, 6, 2, 2, 8, 9, 5, 7, 6, 1, 0, 1, 8, 6, 6, 2, 2, 6, 1, 2, 8, 2, 2, 6, 5, 7, 4, 3, 7, 3, 2, 5, 5, 8, 2, 7, 9, 3, 2, 4, 3, 7, 6, 6, 6, 6, 1, 3, 3, 6, 7, 8, 0, 1, 0, 9, 9, 9, 5, 4, 4, 2, 5, 9, 5, 6, 2, 5, 7, 2, 1, 1, 4, 5, 5, 1, 8, 3, 6, 6, 2, 1, 7, 9, 9, 1, 9, 1, 2, 2, 7, 1, 1, 0, 5, 4, 0, 4, 9, 9, 6, 9, 3, 3, 8, 6, 9, 2, 0, 6, 5, 6, 2, 8, 8, 1, 5, 2, 9, 9, 5, 4, 8, 5, 0, 7, 9, 4, 2, 3, 5, 8, 5, 5, 0, 6, 1, 4, 3, 1, 9, 3, 6, 7, 5, 6, 3, 5, 2, 5, 9, 6, 7, 7, 3, 4, 9, 3, 5, 1, 4, 6, 5, 6, 7, 7, 4, 6, 9, 6, 6, 3, 7, 0, 8, 3, 1, 7, 1, 0, 1, 2, 4, 7, 3, 5, 5, 0, 0, 9, 1, 6, 7, 9, 9, 2, 4, 4, 9, 2, 6, 2, 4, 3, 7, 9, 0, 9, 9, 1, 4, 5, 6, 8, 2, 7, 0, 2, 1, 8, 8, 1, 1, 8, 0, 4, 1, 5, 4, 3, 1, 2, 2, 9, 8, 2, 9, 0, 6, 9, 2, 4, 1, 7, 1, 2, 7, 5, 9, 2, 2, 8, 2, 3, 4, 6, 5, 2, 9, 7, 9, 5, 1, 5, 9, 0, 7, 1, 0, 9, 7, 2, 2, 5, 8, 2, 5, 9, 0, 2, 2, 7, 3, 1, 6, 1, 4, 7, 7, 1, 9, 1, 7, 8, 5, 6, 8, 3, 5, 2, 0, 9, 8, 4, 3, 9, 5, 4, 7, 5, 5, 4, 3, 4, 9, 8, 4, 2, 5, 5, 8, 2, 4, 1, 8, 1, 9, 6, 2, 5, 4, 3, 4, 7, 7, 2, 0, 0, 2, 9, 5, 4, 0, 8, 4, 3, 1, 7, 2, 6, 4, 8, 7, 4, 1, 4, 4, 0, 0, 8, 3, 4, 4, 9, 6, 2, 9, 3, 0, 1, 4, 2, 2, 8, 1, 6, 3, 9, 2, 8, 3, 1, 0, 0, 4]
# [4, 2, 3, 7, 7, 8, 3, 8, 5, 5, 6, 4, 7, 6, 3, 6, 2, 0, 0, 2, 0, 5, 9, 8, 1, 3, 6, 0, 3, 5, 4, 2, 7, 8, 8, 7, 5, 3, 2, 3, 6, 6, 2, 2, 9, 1, 5, 3, 0, 1, 1, 7, 4, 7, 6, 9, 1, 3, 3, 1, 9, 3, 1, 9, 7, 1, 8, 9, 4, 7, 1, 9, 1, 7, 6, 6, 3, 9, 1, 3, 2, 5, 6, 5, 2, 0, 7, 2, 5, 7, 4, 2, 1, 5, 6, 4, 7, 7, 3, 7, 2, 0, 7, 3, 2, 0, 2, 8, 7, 3, 6, 4, 0, 6, 1, 7, 9, 0, 7, 4, 8, 6, 7, 7, 8, 6, 3, 4, 0, 9, 6, 7, 0, 1, 8, 0, 2, 7, 5, 0, 3, 2, 8, 9, 2, 0, 8, 9, 1, 3, 9, 1, 0, 3, 8, 6, 5, 3, 6, 1, 6, 4, 7, 3, 1, 6, 9, 7, 8, 5, 5, 6, 9, 6, 9, 0, 9, 7, 8, 6, 7, 1, 6, 9, 1, 7, 2, 3, 2, 8, 9, 5, 8, 3, 7, 4, 3, 1, 3, 5, 2, 4, 3, 2, 5, 5, 7, 1, 5, 8, 0, 3, 1, 7, 9, 7, 3, 5, 3, 2, 7, 0, 2, 7, 9, 5, 1, 6, 2, 4, 2, 2, 1, 7, 7, 6, 8, 9, 3, 0, 3, 0, 0, 6, 7, 7, 8, 1, 2, 9, 6, 6, 2, 2, 7, 1, 2, 7, 3, 2, 1, 1, 9, 3, 7, 3, 9, 3, 3, 9, 2, 7, 3, 6, 4, 0, 4, 4, 8, 6, 0, 3, 3, 5, 7, 4, 1, 6, 3, 2, 7, 2, 8, 1, 2, 3, 1, 5, 1, 1, 8, 3, 6, 1, 7, 9, 2, 3, 5, 7, 8, 1, 2, 1, 7, 7, 1, 3, 5, 8, 3, 3, 8, 6, 4, 1, 5, 9, 3, 1, 0, 7, 1, 1, 7, 2, 5, 1, 7, 5, 7, 6, 9, 8, 0, 7, 2, 1, 0, 7, 3, 5, 6, 5, 1, 3, 0, 7, 1, 7, 5, 9, 8, 3, 8, 8, 6, 3, 6, 6, 5, 3, 9, 5, 0, 3, 6, 2, 2, 6, 6, 5, 7, 6, 1, 0, 1, 8, 6, 6, 2, 2, 6, 1, 2, 8, 2, 2, 6, 5, 7, 4, 3, 6, 3, 2, 5, 5, 8, 2, 7, 9, 3, 2, 4, 3, 7, 6, 6, 6, 3, 1, 3, 3, 7, 7, 4, 2, 1, 0, 9, 9, 7, 5, 3, 4, 2, 2, 9, 5, 6, 2, 5, 4, 9, 1, 1, 4, 5, 5, 1, 8, 3, 7, 6, 0, 1, 7, 3, 4, 1, 9, 1, 0, 0, 7, 1, 1, 2, 5, 4, 0, 4, 9, 9, 6, 9, 3, 3, 8, 6, 4, 5, 0, 4, 5, 8, 2, 8, 1, 1, 6, 2, 3, 9, 5, 4, 8, 5, 5, 7, 9, 3, 2, 3, 5, 8, 5, 5, 3, 6, 1, 4, 3, 1, 9, 3, 6, 7, 5, 6, 3, 5, 2, 5, 9, 7, 7, 6, 3, 4, 9, 3, 5, 1, 4, 6, 0, 6, 6, 6, 4, 6, 3, 6, 6, 3, 7, 2, 8, 7, 1, 7, 1, 0, 1, 5, 9, 7, 3, 5, 5, 0, 0, 9, 1, 7, 6, 3, 9, 2, 4, 4, 9, 2, 6, 2, 3, 3, 7, 4, 0, 9, 9, 1, 4, 9, 6, 8, 2, 7, 0, 2, 1, 8, 8, 1, 1, 8, 0, 4, 1, 5, 4, 3, 1, 2, 2, 9, 8, 2, 9, 0, 6, 9, 2, 4, 1, 2, 1, 5, 6, 5, 3, 2, 0, 8, 2, 3, 9, 6, 5, 2, 9, 7, 9, 2, 1, 5, 7, 0, 7, 1, 0, 9, 7, 2, 5, 5, 1, 2, 3, 3, 0, 2, 2, 2, 3, 1, 6, 1, 4, 3, 7, 1, 4, 1, 7, 8, 5, 6, 8, 3, 5, 2, 0, 9, 8, 1, 3, 9, 6, 4, 7, 5, 6, 4, 3, 4, 9, 8, 4, 2, 5, 5, 8, 5, 4, 1, 8, 1, 9, 5, 2, 6, 4, 3, 4, 7, 7, 2, 2, 7, 0, 9, 7, 4, 0, 8, 4, 3, 1, 7, 0, 6, 4, 3, 7, 4, 4, 4, 7, 0, 9, 8, 3, 4, 4, 9, 5, 2, 9, 3, 0, 1, 4, 2, 2, 8, 1, 6, 3, 8, 4, 8, 3, 8, 2, 0, 4]

# %%
count = 0
for i in range(len(labels_test)):
    if(labels_test[i] == labels_test_predicted.tolist()[i]):
        count+= 1
print(count, len(labels_test))
# Out:
# 591 760
